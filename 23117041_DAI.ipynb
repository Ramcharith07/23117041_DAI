# %% [markdown]
# <a id="1"></a>
# # <div style="text-align:center; border-radius:15px 50px; padding:15px; color:white; margin:0; font-size:150%; font-family:Pacifico; background-color:#2a6199; overflow:hidden"><b> Laptop Prices </b></div>

# %% [markdown]
# ![LAPTOP PRICES](https://cdn.thewirecutter.com/wp-content/media/2024/07/laptopstopicpage-2048px-3685-2x1-1.jpg?width=1024&quality=75&crop=2:1&auto=webp)

# %% [markdown]
# <a id="1"></a>
# # <div style="text-align:center; border-radius:15px 50px; padding:7px; color:white; margin:0; font-size:110%; font-family:Pacifico; background-color:#3168a1;overflow:hidden"><b>1. Installing Required Libraries</b></div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# <a id="1"></a>
# # <div style="text-align:center; border-radius:15px 50px; padding:7px; color:white; margin:0; font-size:110%; font-family:Pacifico; background-color:#3168a1;overflow:hidden"><b>2. Reading and Understanding our Data</b></div>

# %%
df = pd.read_csv('laptop_prices.csv')
df
# Out:
#      Company                              Product            TypeName  Inches  \
# 0      Apple                          MacBook Pro           Ultrabook    13.3
# 1      Apple                          Macbook Air           Ultrabook    13.3
# 2         HP                               250 G6            Notebook    15.6
# 3      Apple                          MacBook Pro           Ultrabook    15.4
# 4      Apple                          MacBook Pro           Ultrabook    13.3
# ...      ...                                  ...                 ...     ...
# 1270  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1271  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1272  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1273      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1274    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
#       Ram          OS  Weight  Price_euros    Screen  ScreenW  ...  \
# 0       8       macOS    1.37      1339.69  Standard     2560  ...
# 1       8       macOS    1.34       898.94  Standard     1440  ...
# 2       8       No OS    1.86       575.00   Full HD     1920  ...
# 3      16       macOS    1.83      2537.45  Standard     2880  ...
# 4       8       macOS    1.37      1803.60  Standard     2560  ...
# ...   ...         ...     ...          ...       ...      ...  ...
# 1270    4  Windows 10    1.80       638.00   Full HD     1920  ...
# 1271   16  Windows 10    1.30      1499.00  Quad HD+     3200  ...
# 1272    2  Windows 10    1.50       229.00  Standard     1366  ...
# 1273    6  Windows 10    2.19       764.00  Standard     1366  ...
# 1274    4  Windows 10    2.20       369.00  Standard     1366  ...
#
#       RetinaDisplay CPU_company CPU_freq                CPU_model  \
# 0               Yes       Intel      2.3                  Core i5
# 1                No       Intel      1.8                  Core i5
# 2                No       Intel      2.5            Core i5 7200U
# 3               Yes       Intel      2.7                  Core i7
# 4               Yes       Intel      3.1                  Core i5
# ...             ...         ...      ...                      ...
# 1270             No       Intel      2.5            Core i7 6500U
# 1271             No       Intel      2.5            Core i7 6500U
# 1272             No       Intel      1.6  Celeron Dual Core N3050
# 1273             No       Intel      2.5            Core i7 6500U
# 1274             No       Intel      1.6  Celeron Dual Core N3050
#
#      PrimaryStorage  SecondaryStorage PrimaryStorageType  \
# 0               128                 0                SSD
# 1               128                 0      Flash Storage
# 2               256                 0                SSD
# 3               512                 0                SSD
# 4               256                 0                SSD
# ...             ...               ...                ...
# 1270            128                 0                SSD
# 1271            512                 0                SSD
# 1272             64                 0      Flash Storage
# 1273           1024                 0                HDD
# 1274            500                 0                HDD
#
#       SecondaryStorageType  GPU_company               GPU_model
# 0                       No        Intel  Iris Plus Graphics 640
# 1                       No        Intel        HD Graphics 6000
# 2                       No        Intel         HD Graphics 620
# 3                       No          AMD          Radeon Pro 455
# 4                       No        Intel  Iris Plus Graphics 650
# ...                    ...          ...                     ...
# 1270                    No        Intel         HD Graphics 520
# 1271                    No        Intel         HD Graphics 520
# 1272                    No        Intel             HD Graphics
# 1273                    No          AMD          Radeon R5 M330
# 1274                    No        Intel             HD Graphics
#
# [1275 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1275 entries, 0 to 1274
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Company               1275 non-null   object
#  1   Product               1275 non-null   object
#  2   TypeName              1275 non-null   object
#  3   Inches                1275 non-null   float64
#  4   Ram                   1275 non-null   int64
#  5   OS                    1275 non-null   object
#  6   Weight                1275 non-null   float64
#  7   Price_euros           1275 non-null   float64
#  8   Screen                1275 non-null   object
#  9   ScreenW               1275 non-null   int64
#  10  ScreenH               1275 non-null   int64
#  11  Touchscreen           1275 non-null   object
#  12  IPSpanel              1275 non-null   object
#  13  RetinaDisplay         1275 non-null   object
#  14  CPU_company           1275 non-null   object
#  15  CPU_freq              1275 non-null   float64
#  16  CPU_model             1275 non-null   object
#  17  PrimaryStorage        1275 non-null   int64
#  18  SecondaryStorage      1275 non-null   int64
#  19  PrimaryStorageType    1275 non-null   object
#  20  SecondaryStorageType  1275 non-null   object
#  21  GPU_company           1275 non-null   object
#  22  GPU_model             1275 non-null   object
# dtypes: float64(4), int64(5), object(14)
# memory usage: 229.2+ KB

# %% [markdown]
# <h2>Check the NaN values </h2>

# %%
df.isnull().sum()
# Out:
# Company                 0
# Product                 0
# TypeName                0
# Inches                  0
# Ram                     0
# OS                      0
# Weight                  0
# Price_euros             0
# Screen                  0
# ScreenW                 0
# ScreenH                 0
# Touchscreen             0
# IPSpanel                0
# RetinaDisplay           0
# CPU_company             0
# CPU_freq                0
# CPU_model               0
# PrimaryStorage          0
# SecondaryStorage        0
# PrimaryStorageType      0
# SecondaryStorageType    0
# GPU_company             0
# GPU_model               0
# dtype: int64

# %% [markdown]
# <a id="1"></a>
# # <div style="text-align:center; border-radius:15px 50px; padding:7px; color:white; margin:0; font-size:110%; font-family:Pacifico; background-color:#3168a1; overflow:hidden"><b> 3 Check Duplicated Valuesn</b></div>

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns.to_list()
# Out:
# ['Company',
#  'Product',
#  'TypeName',
#  'Inches',
#  'Ram',
#  'OS',
#  'Weight',
#  'Price_euros',
#  'Screen',
#  'ScreenW',
#  'ScreenH',
#  'Touchscreen',
#  'IPSpanel',
#  'RetinaDisplay',
#  'CPU_company',
#  'CPU_freq',
#  'CPU_model',
#  'PrimaryStorage',
#  'SecondaryStorage',
#  'PrimaryStorageType',
#  'SecondaryStorageType',
#  'GPU_company',
#  'GPU_model']

# %%
df['Product'].value_counts()
# Out:
# Product
# XPS 13                                 30
# Inspiron 3567                          25
# 250 G6                                 21
# Vostro 3568                            19
# Legion Y520-15IKBN                     19
#                                        ..
# VivoBook E201NA                         1
# Ideapad 520-15IKBR                      1
# Thinkpad X260                           1
# Rog G752VL-UH71T                        1
# X553SA-XX031T (N3050/4GB/500GB/W10)     1
# Name: count, Length: 618, dtype: int64

# %%
df['Price_euros'].value_counts()
# Out:
# Price_euros
# 1099.0    14
# 1799.0    14
# 1499.0    12
# 1199.0    11
# 1299.0    11
#           ..
# 2090.0     1
# 304.0      1
# 759.0      1
# 1858.0     1
# 764.0      1
# Name: count, Length: 791, dtype: int64

# %%
company = df.groupby("Company")
company

# %% [markdown]
# <a id="1"></a>
# # <div style="text-align:center; border-radius:15px 50px; padding:7px; color:white; margin:0; font-size:110%; font-family:Pacifico; background-color:#3168a1; overflow:hidden"><b> 4. Data Visualization</b></div>

# %%
company.max()[['Product','Price_euros']].plot()
# Out:
# <Axes: xlabel='Company'>

# %%
company.mean(numeric_only=True)[['Inches']].plot()
# Out:
# <Axes: xlabel='Company'>

# %%
pivot = pd.pivot_table(index='TypeName', columns='Screen', data=df, values='Price_euros', aggfunc='count')
pivot
# Out:
# Screen              4K Ultra HD  Full HD  Quad HD+  Standard
# TypeName
# 2 in 1 Convertible          7.0     76.0       7.0      27.0
# Gaming                     13.0    190.0       NaN       2.0
# Netbook                     NaN      4.0       NaN      19.0
# Notebook                   11.0    418.0       3.0     275.0
# Ultrabook                   8.0    123.0      18.0      45.0
# Workstation                 4.0     24.0       NaN       1.0

# %% [markdown]
# <h1>Data Visualization <h1>

# %%
pivot.plot(kind='bar', figsize=(10, 6))
plt.title('Count of Price_euros by TypeName and Screen')
plt.xlabel('TypeName')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Screen')
plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, fmt='.1f', linewidths=2)
plt.xticks(rotation=45)
plt.show()

# %%
sns.countplot(df, x='GPU_company',color='dodgerblue')
plt.title('Count of GPU_company ')
plt.show()

# %%
sns.scatterplot(df, x='Weight', y='Price_euros')
plt.title(' Price_euros and weight')
plt.show()

# %%
df['Company'].value_counts().sort_values(ascending=True).plot(kind='barh',color='dodgerblue')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.title('Name of Company And How many devices')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
df['TypeName'].value_counts().sort_values(ascending=True).plot(kind='barh',color='dodgerblue')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.title('Count of TypeName ')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
df['CPU_model'].value_counts()[:20].sort_values(ascending=True).plot(kind='barh',color='dodgerblue')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.title('Count of GPU_model')
plt.xlabel('Count')
plt.ylabel('CPU_model',fontsize=14)
plt.show()

# %%
sns.countplot(x='Ram',data=df, color='dodgerblue')
plt.title('Count of Ram Size ')
plt.xlabel('Ram Size',fontsize=14,c='k')
plt.show()

# %%
df['OS'].value_counts().sort_values(ascending=True).plot(kind='barh', color='dodgerblue')
plt.title('Count of Operating System  ')
# Out:
# Text(0.5, 1.0, 'Count of Operating System  ')

# %%
sns.countplot(x='Touchscreen',data=df,palette='rocket',hue='Touchscreen',color='dodgerblue')
plt.title('Count of Touch Screen ')
plt.xlabel('Touchscreen',fontsize=14,c='k')
plt.show()

# %%
sns.countplot(x='IPSpanel',data=df,palette='rocket',hue='IPSpanel',color='dodgerblue')
plt.title('Count of IPSpanel')
plt.xlabel('IPSpanel',fontsize=14,c='k')
plt.show()

# %%
plt.figure(figsize=(12,8))

plt.subplot(2, 2, 1)
df['PrimaryStorageType'].value_counts().sort_values(ascending=True).plot(kind='barh', color='dodgerblue')
plt.xlabel('Primary Storage Type')
plt.ylabel('')
plt.subplot(2, 2, 2)
sns.countplot(df, x='PrimaryStorage',color='goldenrod')
plt.xlabel('Primary Storage Space (GB)')
plt.subplot(2, 2, 3)

df['SecondaryStorageType'].value_counts().sort_values(ascending=True).plot(kind='barh', color ='dodgerblue')
plt.xlabel('Secondary Storage Type')
plt.ylabel('')
plt.subplot(2, 2, 4)
sns.countplot(df, x='SecondaryStorage',color='goldenrod')
plt.xlabel('Secondary Storage Space (GB)')

plt.show()

# %%
sns.displot(x='CPU_freq',data=df,kde=True, color='dodgerblue')
plt.xlabel('CPU_freq',fontsize=14)
plt.show()

# %%
sns.scatterplot(x='Weight',y='Price_euros',data=df)
plt.xlabel('Weight',fontsize=14,c='k')
plt.ylabel('Price_euros',fontsize=14,c='k')
plt.show()

# %%
sns.scatterplot(x='CPU_freq',y='Price_euros',data=df)
plt.xlabel('CPU_freq',fontsize=14,c='k')
plt.ylabel('Price_euros',fontsize=14,c='k')
plt.show()

# %%
sns.countplot(x='Screen',hue='Touchscreen',data=df)
plt.xlabel('Screen',fontsize=14,c='k')
plt.ylabel('Count',fontsize=14,c='k')
plt.show()

# %%
sns.barplot(y='PrimaryStorage',hue='PrimaryStorageType',data=df,estimator=np.mean)
plt.xlabel('PrimaryStorage',fontsize=14,c='k')
plt.ylabel('Count',fontsize=14,c='k')
plt.show()

# %%
sns.barplot(x='GPU_company',y='Price_euros',data=df,estimator=np.mean,hue='GPU_company')
plt.xlabel('GPU_company',fontsize=14,c='k')
plt.ylabel('Price_euros',fontsize=14,c='k')
plt.show()

# %%
sns.barplot(x='PrimaryStorageType',y='Price_euros',data=df,estimator=np.mean,hue='PrimaryStorageType')
plt.xlabel('PrimaryStorageType',fontsize=14,c='k')
plt.ylabel('Price_euros',fontsize=14,c='k')
plt.show()

# %%
sns.relplot(x='CPU_freq',y='Price_euros',data=df,hue='CPU_company',col='CPU_company',col_wrap=3)
plt.xlabel('CPU_freq',fontsize=14,c='k')
plt.ylabel('Price_euros',fontsize=14,c='k')
plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True,cbar=False,cmap='Blues')
plt.title('Heatmap')
plt.show()
